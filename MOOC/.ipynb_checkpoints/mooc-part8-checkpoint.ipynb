# %%
'''Please write a function named smallest_average(person1: dict, person2: dict, person3: dict), which takes three dictionary objects as its arguments.

Each dictionary object contains values mapped to the following keys:

"name": The name of the contestant
"result1": the first result of the contestant (an integer between 1 and 10)
"result2": the second result of the contestant (as above)
"result3": the third result of the contestant (as above)
The function should calculate the average of the three results for each contestant, and then return the contestant whose average result was the smallest. The return value should be the entire dictionary object containing the contestant's information.

You may assume there will be no ties, i.e. a single contestant will have the smallest average result.
'''

def smallest_average(p1, p2, p3):
    smallest = min(
        (p1, p2, p3),
        key=lambda p: p["result1"] + p["result2"] + p["result3"]
    )
    return smallest
   
    '''r1 = p1['result1'] + p1['result2'] + p1['result3'] tein tämän ratkaisun ensiksi, mutta lamdalla ratkaisu on fiksumpi ja python tyylinen
    r2 = p2['result1'] + p2['result2'] + p2['result3'] 
    r3 = p3['result1'] + p3['result2'] + p3['result3'] 

    if r1 < r2 and r1 < r3:
        smallest = p1
    elif r2 < r3:
        smallest = p2
    else:
        smallest = p3
    return smallest'''



person1 = {"name": "Mary", "result1": 2, "result2": 3, "result3": 3}
person2 = {"name": "Gary", "result1": 5, "result2": 1, "result3": 8}
person3 = {"name": "Larry", "result1": 3, "result2": 1, "result3": 1}

print(smallest_average(person1, person2, person3))
# Out:
# {'name': 'Larry', 'result1': 3, 'result2': 1, 'result3': 1}

# %%
def row_sums(my_matrix: list):
    '''for row in my_matrix:
        total = 0
        for value in row:
            total += value
        row.append(total)'''

    return [row + [sum(row)] for row in my_matrix] #Python-tyylinen list comprehension ratkaisu
        

my_matrix = [[1, 2], [3, 4]]
my_matrix = row_sums(my_matrix)
print(my_matrix)
# Out:
# [[1, 2, 3], [3, 4, 7]]

# %%
from datetime import date

def list_years(list):
    list_of_years = []
    for date in list:
        list_of_years.append(date.year)
    return sorted(list_of_years)

date1 = date(2019, 2, 3)
date2 = date(2006, 10, 10)
date3 = date(1993, 5, 9)

years = list_years([date1, date2, date3])
print(years)
# Out:
# [1993, 2006, 2019]

# %%
class BankAccount():
    def __init__(self, owner, balance):
        self.owner = owner
        self.balance = balance
    def add_to_account(self,value):
        self.balance = self.balance + value
        
    def get_info(self):
        return (f'Name: {self.owner}, Balance: {self.balance}')

frank_account = BankAccount('Frank', 50)
paula_account = BankAccount('Paula', 100)

print(frank_account.balance)
print(paula_account.get_info())

frank_account.add_to_account(100)
print(frank_account.get_info())
# Out:
# 50
# Name: Paula, Balance: 100
# Name: Frank, Balance: 150

# %%
'''
Please write a class named Book with the attributes name, author, genre and year, along with a constructor which assigns initial values to these attributes.

Your class should work like this:

python = Book("Fluent Python", "Luciano Ramalho", "programming", 2015)
everest = Book("High Adventure", "Edmund Hillary", "autobiography", 1956)

print(f"{python.author}: {python.name} ({python.year})")
print(f"The genre of the book {everest.name} is {everest.genre}")
'''

class Book:

    def __init__(self, name, author, genre, year):
        self.name = name
        self.author = author
        self.genre = genre
        self.year = year
    
    def get_info(self):
        print(f'Book name: {self.name}, Author: {self.author}, Genre: {self.genre}, Year: {self.year}')

kirja1 = Book('Python Things', 'Pekka Programmer', 'Educational', 1990)
kirja2 = Book('Alchemist', 'Pauolo Coelho', 'Fiction', 1997)

kirja1.get_info()
kirja2.get_info()
# Out:
# Book name: Python Things, Author: Pekka Programmer, Genre: Educational, Year: 1990
# Book name: Alchemist, Author: Pauolo Coelho, Genre: Fiction, Year: 1997

# %%
class Checklist:
    def __init__(self,header: str,entries: list):
        self.header = header
        self.entries = entries
class Customer:
    def __init__(self,id: str,balance: float,discount: int):
        self.id = id
        self.balance = balance
        self.discount = discount
class Cable:
    def __init__(self,model: str,length: float,max_speed: int,bidirectional: bool):
        self.model = model
        self.length = length
        self.max_speed = max_speed
        self.bidirectional = bidirectional

# %%
'''
Please define the class Pet. The class should include a constructor,
which takes the initial values of the attributes name, species and year_of_birth as its arguments, in that specific order.

Please also write a function named new_pet(name: str, species: str, year_of_birth: int) outside the class definition. 
The function should create and return a new object of type Pet, as defined in the class Pet.
'''

class Pet:
    def __init__(self,name: str, species: str,year_of_birth: int):
        self.name = name
        self.species = species
        self.year_of_birth = year_of_birth

def new_pet(name: str, species: str, year_of_birth: int):
    #pet1 = Pet(name,species,year_of_birth)
    return Pet(name,species,year_of_birth)

fluffy = new_pet('Fluffy','Chihu',2020)
print(fluffy.name)
# Out:
# Fluffy

# %%
def older_book(book1, book2):
    if book1.year < book2.year:
        print(f'{book1.name} is older, it was published in {book1.year}')
    elif book2.year < book1.year:
        print(f'{book2.name} is older, it was published in {book2.year}')
    else:
        print(f'{book1.name} and {book2.name} were published in {book2.year}')


python = Book("Fluent Python", "Luciano Ramalho", "programming", 2015)
everest = Book("High Adventure", "Edmund Hillary", "autobiography", 1956)
norma = Book("Norma", "Sofi Oksanen", "crime", 2015)

older_book(python, everest)
older_book(norma, everest)
older_book(python, norma)
# Out:
# High Adventure is older, it was published in 1956
# High Adventure is older, it was published in 1956
# Fluent Python and Norma were published in 2015

# %%
'''
Please write a function named books_of_genre(books: list, genre: str) which takes a list of objects of type Book 
and a string representing a genre as its arguments.
    The function should return a new list, which contains the books with the desired genre from the original list. 
Please see the examples below.
'''
def books_of_genre(books: list, genre: str):
    books_to_match_genre = []
    for book in books:
        if book.genre == genre:
            books_to_match_genre.append(book)
            
    return books_to_match_genre

books = [python, everest, norma, Book("The Snowman", "Jo Nesbø", "crime", 2007)]

print("Books in the crime genre:")
for book in books_of_genre(books, "crime"):
    print(f"{book.author}: {book.name}")

#Books in the crime genre:
#Sofi Oksanen: Norma
#Jo Nesbø: The Snowman
# Out:
# Books in the crime genre:
# Sofi Oksanen: Norma
# Jo Nesbø: The Snowman

# %%
#MOOC part8 - 4. defining methods

# %%
class DecreasingCounter:
    def __init__(self, initial_value: int):
        self.value = initial_value
        self.original_val = self.value
        

    def print_value(self):
        print("value:", self.value)

    def decrease(self):
        if self.value > 0:
            self.value = self.value - 1

    def set_to_zero(self):
        self.value = 0

    def reset_original_value(self):
        self.value = self.original_val
        
        
counter = DecreasingCounter(13)
counter.print_value()
counter.decrease() 
counter.print_value()
counter.set_to_zero()
counter.print_value()
counter.reset_original_value()
counter.print_value()
# Out:
# value: 13
# value: 12
# value: 0
# value: 13

# %%
class Person:
    def __init__(self, name: str):
        self.name = name
    def return_first_name(self):
        first_name = self.name.split()[0]
        return first_name
    def return_last_name(self):
        last_name = self.name.split()[1]
        return last_name

if __name__ == "__main__":
    peter = Person("Peter Pythons")
    print(peter.return_first_name())
    print(peter.return_last_name())

    paula = Person("Paula Pythonnen")
    print(paula.return_first_name())
    print(paula.return_last_name())
# Out:
# Peter
# Pythons
# Paula
# Pythonnen

# %%
class NumberStats:
    def __init__(self):
        self.numbers = 0
        self.list_of_numbers = []
    def add_number(self, number:int):
        self.numbers += 1
        self.list_of_numbers.append(number)
    def count_numbers(self):
        return self.numbers
    def get_sum(self):
        
        if len(self.list_of_numbers) > 0:
            return sum(self.list_of_numbers)
        else:
            return 0
    def average(self):
        if self.numbers > 0:
            return sum(self.list_of_numbers) / self.numbers
        else:
            return 0
        

stats = NumberStats()
stats_even = NumberStats()
stats_odd = NumberStats()
while True:
    user_input = int(input('Please type in integer numbers: ')) # -1 quits
    if user_input == -1:
        break
    elif user_input % 2 == 0:
        stats_even.add_number(user_input)
    elif user_input % 2 != 0:
        stats_odd.add_number(user_input)
    stats.add_number(user_input)
print(f'Sum of numbers: {stats.get_sum()}')
print(f'Average: {stats.average()}')
print(f'Sum of even: {stats_even.numbers}')
print(f'Sum of odd: {stats_odd.numbers}')
# Out:
# Please type in integer numbers:  3
# Please type in integer numbers:  5
# Please type in integer numbers:  6
# Please type in integer numbers:  3
# Please type in integer numbers:  8
# Please type in integer numbers:  -1
# Sum of numbers: 25
# Average: 5.0
# Sum of even: 2
# Sum of odd: 3

# %%
#PART8 - 5. More examples

# %%
class Stopwatch:
    def __init__(self, seconds:int, minutes:int):
        self.seconds = seconds
        self.minutes = minutes
    def tick(self):
        self.seconds += 1
        if self.seconds == 60:
            self.seconds = 0
            self.minutes +=1
        if self.minutes == 60:
            self.minutes = 0
    def __str__(self):
        return f"{self.minutes:02d}:{self.seconds:02d}"
        

watch = Stopwatch(55,55)
for i in range(3600):
    print(watch)
    watch.tick() #when reaches 59:59 -> goes back to 00:00

# %%
class Clock:
    def __init__(self,hours:int, minutes:int, seconds:int):
        self.seconds = seconds
        self.minutes = minutes
        self.hours = hours
    def tick(self):
        self.seconds += 1
        if self.seconds == 60:
            self.seconds = 0
            self.minutes +=1
        if self.minutes == 60:
            self.minutes = 0
            self.hours += 1
        if self.hours == 24:
            self.hours = 0
    def set(self,hour, minute):
        self.hours = hour
        self.minute = minute
        self.seconds = 0
    def __str__(self):
        return f"{self.hours:02d}:{self.minutes:02d}:{self.seconds:02d}"
def run():
    clock = Clock(23, 59, 55)
    print(clock)
    clock.tick()
    print(clock)
    clock.tick()
    print(clock)
    clock.tick()
    print(clock)
    clock.tick()
    print(clock)
    clock.tick()
    print(clock)
    clock.tick()
    print(clock)

    clock.set(3,30)
    print(clock)
    clock.tick()
    print(clock)
    clock.tick()
    print(clock)
run()
# Out:
# 23:59:55
# 23:59:56
# 23:59:57
# 23:59:58
# 23:59:59
# 00:00:00
# 00:00:01
# 03:00:00
# 03:00:01
# 03:00:02

# %%
class LunchCard:
    def __init__(self, balance: float):
        self.balance = float(balance)
        self.lunch = 2.60
        self.special = 4.60

    def eat_lunch(self):
        if self.balance - self.lunch > 0:
            self.balance -= self.lunch

    def eat_special(self):
        if self.balance - self.special > 0:
            self.balance -= self.special

    def deposit_money(self,depo: int):
        self.balance += depo

    def __str__(self):
        return f'Balance on the card is {float(self.balance):.2f}'
        

def run():
    card = LunchCard(5)
    print(card)

    card.eat_lunch()
    print(card)

    card.eat_special()
    card.eat_lunch()
    card.deposit_money(100)
    print(card)
run()
# Out:
# Balance on the card is 5.00
# Balance on the card is 2.40
# Balance on the card is 102.40
