# %%
import numpy as np

print('Numpy version: ', np.__version__)
print(dir(np))
# Out:
# Numpy version:  2.3.4
# ...

# %%
test_list = [1,2,3,4,5,6]

numpy_test_list_array = np.array(test_list)

print(numpy_test_list)
print(type(numpy_test_list))
# Out:
# [1 2 3 4 5 6]
# <class 'numpy.ndarray'>

# %%
int_to_float_list = [1,4,50,100]
int_to_float_array = np.array(int_to_float_list, dtype=float)
print(int_to_float_array) # tulostaa [  1.   4.  50. 100.], eli np.array lisää desimaalin joka osoittaa int -> float

c = np.array(int_to_float_list, dtype=bool)
print(numpy_bool_array)
# Out:
# [  1.   4.  50. 100.]
# [ True  True  True  True]

# %%
list_2d = [[1,2,3],[4,5,6],[7,8,9]]
numpy_2d = np.array(list_2d)

print(numpy_2d)
# Out:
# [[1 2 3]
#  [4 5 6]
#  [7 8 9]]

# %%
np_to_list = numpy_test_list_array.tolist() #np array can be converted back to the list using .tolist()
print(np_to_list)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
tuple = (1,2,3,4,5,6)
print(type(tuple)) #checking type
print('This tuple contains: ', tuple)

array_from_tuple = np.array(tuple) #we can use the same .array() method as with lists to convert tuples to np.arrays
print(type(array_from_tuple))
print('This is numpy array and contains: ', array_from_tuple)
# Out:
# <class 'tuple'>
# This tuple contains:  (1, 2, 3, 4, 5, 6)
# <class 'numpy.ndarray'>
# This is numpy array and contains:  [1 2 3 4 5 6]
